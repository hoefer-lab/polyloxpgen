# %%
import zipfile
import numpy as np
import pandas as pd
import polylox_pgen
import polylox_merge

# %%
barcodelib, minrecs, path_matrix = barcode_pipeline.load_data(path_type='ld_2017') # path_type='ld_2017'

# %%
barcodelib, minrecs, path_matrix_uniform = barcode_pipeline.load_data(path_type='uniform')

# %%
type(minrecs[0])
# Out:
# numpy.int64

# %%
barcode_pipeline.main() # path_type='ld_2017' or 'uniform' (default)
# Out:
# Loading Data ... Done

# %%
path_matrix
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 1.42566052e-02, ...,
#         3.18916743e-06, 0.00000000e+00, 3.42407195e-07],
#        [0.00000000e+00, 3.02617271e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 7.32060341e-07, 0.00000000e+00],
#        [0.00000000e+00, 3.02617271e-02, 0.00000000e+00, ...,
#         0.00000000e+00, 7.32721296e-07, 0.00000000e+00],
#        ...,
#        [0.00000000e+00, 0.00000000e+00, 7.03540322e-04, ...,
#         4.13788830e-02, 4.79731871e-02, 5.14228488e-02],
#        [0.00000000e+00, 1.92084769e-02, 2.79877619e-02, ...,
#         1.15654101e-01, 1.30052112e-01, 1.31712925e-01],
#        [0.00000000e+00, 0.00000000e+00, 2.04108894e-02, ...,
#         1.20815361e-01, 1.24523513e-01, 1.37079234e-01]])

# %%
sum(path_matrix)
# Out:
# array([1.        , 1.        , 1.        , 1.        , 1.        ,
#        1.        , 1.        , 1.        , 1.00000431, 1.00000431,
#        1.00001002])

# %% [markdown]
# ##### merge files

# %%
### USER INPUT
location_files_in = ['./tests/bc1020.barcode.count.txt', './tests/bc1020.barcode.count.txt', './tests/bc1022.barcode.count.txt']
sample_names =  ['Sample1', 'Sample1B', 'Sample2']

location_dir_out = './examples/'
file_name_out = 'bc10201022_merged'
###

polylox_merge.validate_user_input(location_files_in, sample_names, location_dir_out, file_name_out)
polylox_merge.create_outdir(location_dir_out)

# %%
df = collect_files(location_files_in, sample_names)

# %%
df
# Out:
#             Sample1  Sample1B  Sample2
# Barcode
# 123456789     33813     33813    38072
# 1                88        88       47
# 123              71        71       12
# 12349            57        57        0
# GFE               0         0       93
# 1236789          22        22       48
# 16789            42        42        0
# 3FED789          40        40        0
# 123HGFED9        35        35        0
# 1B9              34        34        0
# 3456789           7         7       51
# 18769            23        23        0
# 789              13        13       18
# IHGF123          22        22        0
# 1234569           0         0       43
# 129              12        12       15
# 123456GHI        17        17        0
# 349               0         0       34
# 5                 0         0       33
# 169              16        16        0
# 9                 3         3       25
# 12789             0         0       29
# EBA              12        12        0
# ...

# %%
df.to_csv(location_dir_out + file_name_out + '.txt', sep='\t')

# %%
read_single_file(location_files_in[0], sample_names[0])
# Out:
#       Barcode  Sample1
# 0   123456789    33813
# 1           1       88
# 2         123       71
# 3       12349       57
# 4       16789       42
# 5     3FED789       40
# 6   123HGFED9       35
# 7         1B9       34
# 8       18769       23
# 9     1236789       22
# 10    IHGF123       22
# 11  123456GHI       17
# 12        169       16
# 13        789       13
# 14        129       12
# 15        EBA       12
# 16      EDCB9       10
# 17          C        9
# 18    3456789        7
# 19      123F7        6
# 20    56CBA89        6
# 21        G89        6
# 22    1456789        4
# 23          3        4
# 24          E        4
# 25          9        3
# 26    G456C89        3
# 27  12EDC6789        2
# 28        I6A        2
# 29  1234X6789        1
# 30         19        1
# 31  1X3456X89        1

# %%
df
# Out:
#             Sample1  Sample2
# Barcode
# 123456789   33813.0  38072.0
# 1              88.0     47.0
# GFE             0.0     93.0
# 123            71.0     12.0
# 1236789        22.0     48.0
# 3456789         7.0     51.0
# 12349          57.0      0.0
# 1234569         0.0     43.0
# 16789          42.0      0.0
# 3FED789        40.0      0.0
# 123HGFED9      35.0      0.0
# 349             0.0     34.0
# 1B9            34.0      0.0
# 5               0.0     33.0
# 789            13.0     18.0
# 12789           0.0     29.0
# 9               3.0     25.0
# 129            12.0     15.0
# I               0.0     23.0
# 18769          23.0      0.0
# IHGF123        22.0      0.0
# 123456GHI      17.0      0.0
# 1456789         4.0     12.0
# 169            16.0      0.0
# 3HGFED9         0.0     14.0
# 3               4.0      9.0
# EBA            12.0      0.0
# E67BC           0.0     11.0
# EDCB9          10.0      0.0
# C               9.0      0.0
# ...

# %%
df_merged
# Out:
#             Sample1  Sample2
# Barcode
# 123456789   33813.0  38072.0
# 1              88.0     47.0
# GFE             0.0     93.0
# 123            71.0     12.0
# 1236789        22.0     48.0
# 3456789         7.0     51.0
# 12349          57.0      0.0
# 1234569         0.0     43.0
# 16789          42.0      0.0
# 3FED789        40.0      0.0
# 123HGFED9      35.0      0.0
# 349             0.0     34.0
# 1B9            34.0      0.0
# 5               0.0     33.0
# 789            13.0     18.0
# 12789           0.0     29.0
# 9               3.0     25.0
# 129            12.0     15.0
# I               0.0     23.0
# 18769          23.0      0.0
# IHGF123        22.0      0.0
# 123456GHI      17.0      0.0
# 1456789         4.0     12.0
# 169            16.0      0.0
# 3HGFED9         0.0     14.0
# 3               4.0      9.0
# EBA            12.0      0.0
# E67BC           0.0     11.0
# EDCB9          10.0      0.0
# C               9.0      0.0
# ...

# %%
df_new
# Out:
#             Sample1  Sample2
# Barcode
# 1              88.0     47.0
# 123            71.0     12.0
# 12345678        0.0      1.0
# 123456789   33813.0  38072.0
# 12345678X       0.0      1.0
# 1234569         0.0     43.0
# 123456GHI      17.0      0.0
# 123456X89       0.0      1.0
# 123456X8X       0.0      1.0
# 12349          57.0      0.0
# 1234X6789       1.0      0.0
# 1236789        22.0     48.0
# 123F5DG89       0.0      9.0
# 123F7           6.0      0.0
# 123FED789       0.0      8.0
# 123HGFED9      35.0      0.0
# 12789           0.0     29.0
# 129            12.0     15.0
# 12EDC6789       2.0      0.0
# 1456789         4.0     12.0
# 149             0.0      7.0
# 16789          42.0      0.0
# 169            16.0      0.0
# 18769          23.0      0.0
# 19              1.0      0.0
# 1B9            34.0      0.0
# 1HGFEDCB9       0.0      1.0
# 1X3456X89       1.0      0.0
# 3               4.0      9.0
# 3456789         7.0     51.0
# ...

# %%
validate_user_input(location_files, sample_names, location_out)

# %% [markdown]
# ##### read in test txt files

# %%
data_barcodes = np.loadtxt('bc1020.barcode.count.txt', usecols=0, delimiter='\t', dtype=str)

# %%
data_reads = np.loadtxt('bc1020.barcode.count.txt', usecols=1, delimiter='\t')
data_reads = data_reads.reshape(len(data_reads), 1)
data_reads
# Out:
# array([[3.4925e+04],
#        [3.4386e+04],
#        [3.3813e+04],
#        [8.8000e+01],
#        [7.1000e+01],
#        [5.7000e+01],
#        [4.2000e+01],
#        [4.0000e+01],
#        [3.5000e+01],
#        [3.4000e+01],
#        [2.3000e+01],
#        [2.2000e+01],
#        [2.2000e+01],
#        [1.7000e+01],
#        [1.6000e+01],
#        [1.3000e+01],
#        [1.2000e+01],
#        [1.2000e+01],
#        [1.0000e+01],
#        [9.0000e+00],
#        [7.0000e+00],
#        [6.0000e+00],
#        [6.0000e+00],
#        [6.0000e+00],
#        [4.0000e+00],
#        [4.0000e+00],
#        [4.0000e+00],
#        [3.0000e+00],
#        [3.0000e+00],
#        [2.0000e+00],
#        [2.0000e+00],
#        [1.0000e+00],
#        [1.0000e+00],
#        [1.0000e+00]])

# %%
# purged_barcodes, purged_reads, data_minrecs, data_pgens = barcode_pipeline.main(path_matrix_type='ld_2017')
purged_barcodes, purged_reads, data_minrecs, data_pgens = barcode_pipeline.main()
# Out:
# Loading data ... Done
# Purging barcodes and reads ... Done
# Finding minimal recombinations ... Done
# Computing generation probabilities ... Done

# %%
purged_barcodes, purged_reads, data_minrecs, data_pgens
# Out:
# (array(['123456789', '1', '123', '12349', '16789', '3FED789', '123HGFED9',
#         '1B9', '18769', '1236789', 'IHGF123', '123456GHI', '169', '789',
#         '129', 'EBA', 'EDCB9', 'C', '3456789', '123F7', '56CBA89', 'G89',
#         '1456789', '3', 'E', '9', 'G456C89', '12EDC6789', 'I6A'],
#        dtype='<U9'),
#  array([[3.3813e+04],
#         [8.8000e+01],
#         [7.1000e+01],
#         [5.7000e+01],
#         [4.2000e+01],
#         [4.0000e+01],
#         [3.5000e+01],
#         [3.4000e+01],
#         [2.3000e+01],
#         [2.2000e+01],
#         [2.2000e+01],
#         [1.7000e+01],
#         [1.6000e+01],
#         [1.3000e+01],
#         [1.2000e+01],
#         [1.2000e+01],
#         [1.0000e+01],
#         [9.0000e+00],
#         [7.0000e+00],
#         [6.0000e+00],
#         [6.0000e+00],
#         [6.0000e+00],
#         [4.0000e+00],
#         [4.0000e+00],
#         [4.0000e+00],
#         [3.0000e+00],
#         [3.0000e+00],
#         [2.0000e+00],
# ...

# %%
import pandas as pd

# %%
df_test = pd.read_csv('bc1020_BarPipe.txt', sep='\t')

# %%
df_test.purged_codes == purged_barcodes
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# Name: purged_codes, dtype: bool

# %%
df_test.purged_reads == purged_reads[:, 0]
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# Name: purged_reads, dtype: bool

# %%
df_test.minimal_recom == data_minrecs
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# Name: minimal_recom, dtype: bool

# %%
df_test.pgen - data_pgens
# Out:
# 0     5.325895e-04
# 1    -4.904016e-03
# 2    -4.165851e-03
# 3    -1.879551e-03
# 4    -1.879551e-03
# 5     7.151937e-05
# 6    -2.993014e-03
# 7    -8.389037e-04
# 8    -1.940418e-08
# 9     2.874207e-03
# 10    1.970448e-05
# 11    2.424256e-05
# 12   -7.788163e-05
# 13   -4.165851e-03
# 14   -4.179478e-03
# 15    2.413033e-05
# 16   -1.468220e-04
# 17   -7.250106e-04
# 18    2.870980e-03
# 19    3.628824e-05
# 20   -2.738033e-06
# 21   -8.384245e-04
# 22    2.872353e-03
# 23   -6.358777e-04
# 24   -6.767807e-04
# 25   -4.904016e-03
# 26   -5.836527e-06
# 27   -4.482603e-04
# 28   -1.308062e-05
# Name: pgen, dtype: float64

# %%
np.allclose(df_test.pgen, data_pgens)
# Out:
# False

# %%
np.loadtxt('./tests/bc1020_BarPipe.txt', usecols=0, skiprows=1, delimiter='\t', dtype=str)
# Out:
# array(['123456789', '1', '123', '12349', '16789', '3FED789', '123HGFED9',
#        '1B9', '18769', '1236789', 'IHGF123', '123456GHI', '169', '789',
#        '129', 'EBA', 'EDCB9', 'C', '3456789', '123F7', '56CBA89', 'G89',
#        '1456789', '3', 'E', '9', 'G456C89', '12EDC6789', 'I6A'],
#       dtype='<U9')

# %%
purged_barcodes, purged_reads = purge(data_barcodes, data_reads, barcodelib)

# %%
purged_minrecs = get_purged_minrecs(purged_barcodes, minrecs)

# %%
purged_minrecs
# Out:
# array([0, 1, 1, 1, 1, 2, 1, 2, 4, 1, 3, 3, 2, 1, 1, 3, 2, 2, 1, 3, 3, 2,
#        1, 2, 2, 1, 3, 1, 3])

# %%
minrec_distr = compute_minrec_distr(purged_minrecs)

# %%
minrec_distr
# Out:
# array([0.03448276, 0.4137931 , 0.27586207, 0.24137931, 0.03448276,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        ])

# %%
minrec_distr
# Out:
# array([0.03448276, 0.4137931 , 0.27586207, 0.24137931, 0.03448276,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        ])

# %%
np.sum(minrec_distr)
# Out:
# 1.0

# %%
path_matrix.shape
# Out:
# (1866890, 11)

# %%
pgens = compute_pgens(purged_barcodes, minrec_distr, barcodelib, path_matrix)

# %%
pgens
# Out:
# array([3.84355584e-02, 2.94879544e-02, 1.14167763e-02, 9.42796524e-03,
#        9.42796524e-03, 4.50198714e-04, 6.37456534e-03, 1.61111324e-03,
#        1.42324091e-08, 1.26408941e-02, 5.99052437e-05, 4.01358461e-05,
#        9.86907483e-04, 1.14167763e-02, 1.14031500e-02, 1.97213637e-04,
#        2.61783761e-04, 2.30242369e-03, 1.26376670e-02, 1.01953706e-04,
#        1.93810269e-05, 1.61159244e-03, 1.26390402e-02, 2.91898248e-03,
#        1.54909588e-03, 2.94879544e-02, 3.16649009e-05, 8.92461708e-03,
#        5.65756829e-05])

# %%
pgens = np.dot(purged_path_matrix, minrec_distr)

# %%
pgens.shape
# Out:
# (29,)

# %%
pgens
# Out:
# array([3.84355584e-02, 2.94879544e-02, 1.14167763e-02, 9.42796524e-03,
#        9.42796524e-03, 4.50198714e-04, 6.37456534e-03, 1.61111324e-03,
#        1.42324091e-08, 1.26408941e-02, 5.99052437e-05, 4.01358461e-05,
#        9.86907483e-04, 1.14167763e-02, 1.14031500e-02, 1.97213637e-04,
#        2.61783761e-04, 2.30242369e-03, 1.26376670e-02, 1.01953706e-04,
#        1.93810269e-05, 1.61159244e-03, 1.26390402e-02, 2.91898248e-03,
#        1.54909588e-03, 2.94879544e-02, 3.16649009e-05, 8.92461708e-03,
#        5.65756829e-05])

# %%
sum(purged_path_matrix[0, :] * minrec_distr)
# Out:
# 0.03843555841359923

# %%
purged_path_matrix[0, :]
# Out:
# array([1.00000000e+00, 0.00000000e+00, 1.42566052e-02, 0.00000000e+00,
#        5.78352507e-04, 0.00000000e+00, 3.70858459e-05, 0.00000000e+00,
#        3.18916743e-06, 0.00000000e+00, 3.42407195e-07])

# %%
minrec_distr
# Out:
# array([0.03448276, 0.4137931 , 0.27586207, 0.24137931, 0.03448276,
#        0.        , 0.        , 0.        , 0.        , 0.        ,
#        0.        ])

# %%
pgens_uniform = compute_pgens(purged_barcodes, minrec_distr, barcodelib, path_matrix_uniform)

# %%
pgens_uniform
# Out:
# array([3.79029690e-02, 3.43919704e-02, 1.55826275e-02, 1.13075167e-02,
#        1.13075167e-02, 3.78679342e-04, 9.36757958e-03, 2.45001695e-03,
#        3.36365882e-08, 9.76668680e-03, 4.02007641e-05, 1.58932879e-05,
#        1.06478911e-03, 1.55826275e-02, 1.55826275e-02, 1.73083309e-04,
#        4.08605726e-04, 3.02743428e-03, 9.76668680e-03, 6.56654695e-05,
#        2.21190600e-05, 2.45001695e-03, 9.76668680e-03, 3.55486015e-03,
#        2.22587659e-03, 3.43919704e-02, 3.75014279e-05, 9.37287735e-03,
#        6.96563000e-05])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(np.log(pgens), np.log(pgens_uniform))
